# %% [markdown]
# # BLAZE - Ballistic Launch Analyser and Zenith Estimator

# %%
import warnings
from BLAZE import *
from Flight_Eqns import *
warnings.filterwarnings("ignore")

# %%
results = blaze(v_0 = None, v_t = None, h_apg = None, t_apg = 3.24, t_diff = 1.48)
# Out:
# BLAZE Correlation Results for Ballistic Rocket
#
# Burnout Velocity:              74.161
# Terminal Velocity:             24.840
# Velocity at Touchdown:        -23.674
# Time to Burnout:                0.081
# Time to Apogee:                 3.240
# Time to Touchdown:              7.960
# Time Difference:                1.480
# Apogee / Maximum Height:       75.142

# %%
# Plot the graph for velocity and height vs time for the flight.
v_0, v_t, v_end, t_0, t_apg, t_end, t_diff, h_apg = results
plot_vt_ht(t_0, t_apg, t_end, v_t, h_apg)
